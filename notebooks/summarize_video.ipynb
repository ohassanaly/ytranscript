# %% [markdown]
# Given a YT video URL:
# - retrieve the text transcript
# - produce a summary

# %%
from utils import get_youtube_video_id, retrieve_video_transcript
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
video_url = "https://www.youtube.com/watch?v=01rldii7b_Q"
transcript = retrieve_video_transcript(video_url)

# %%
prompt = f"""Provide a summary of the given video transcript

video transcript: {transcript}
"""

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
answer = llm.invoke(prompt).content

print(answer)
# Out:
# The video discusses the latest innovations in the C3 Agentic AI platform aimed at enhancing the developer experience for onboarding, building, deploying, and operating applications. Jake Whitam, who leads developer experience at C3, and Josh Prisbilo, the lead product manager, present a live demo showcasing the platform's capabilities.
#
# Key highlights include:
#
# 1. **Pre-built Applications**: The platform offers 131 pre-built AI applications that come with preconfigured data pipelines, AI models, application logic, and user interfaces, allowing for rapid deployment and scaling.
#
# 2. **Developer Experience Enhancements**: The team has focused on improving the onboarding process, providing advanced training courses, integrated development tools, and real-time support through a redesigned community forum. This aims to foster self-sufficiency among developers.
#
# ...
