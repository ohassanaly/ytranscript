# %%
from utils import get_youtube_video_id, retrieve_video_transcript
import json
from tqdm import tqdm
import time
import random
import logging

# %%
with open("snowflakedevelopers_videos.json", "r", encoding="utf-8") as f:
    data = json.load(f)

out_path = "snowflakedevelopers_transcripts.jsonl"


logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s %(levelname)s [%(name)s] %(message)s",
    filename="full_extract.log",
    filemode="a",  # append
)

logger = logging.getLogger(__name__)

# %%
result = {}
for title, url in tqdm(data.items()):
    try:
        record = {
            "url": url,
            "title": title,
            "transcript": retrieve_video_transcript(url),
        }
    except Exception:
        logger.exception("Failed processing url=%s", url)
        record = {"url": url, "title": title, "transcript": ""}
    #saving transcripts one by one
    with open(out_path, "a", encoding="utf-8") as f:
        f.write(json.dumps(record, ensure_ascii=False) + "\n")
        f.flush()

    time.sleep(random.uniform(2, 5)) #presumably, the API is rate-limited to 5 requests per 10 seconds
# Out:
#   4%|███                                                                            | 41/1066 [03:20<1:23:30,  4.89s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       2 for title, url in tqdm(data.items()):
#       3     try:
#       4         record = {
#       5             "url": url,
#       6             "title": title,
# ----> 7             "transcript": retrieve_video_transcript(url),
#       8         }
#       9     except Exception:
#      10         logger.exception("Failed processing url=%s", url)
#
# File ~/work/ytranscript/notebooks/utils.py:39, in retrieve_video_transcript(video_url)
#      37 full_text=""
#      38 try :
# ---> 39     fetched_transcript = ytt_api.fetch(video_id)
#      40 except Exception as e:
#      41     logger.error(
#      42         "Failed to fetch transcript for video_url=%s: %s",
#      43         video_url,
#      44         e
#      45     )
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_api.py:71, in YouTubeTranscriptApi.fetch(self, video_id, languages, preserve_formatting)
#      51 def fetch(
#      52     self,
#      53     video_id: str,
#      54     languages: Iterable[str] = ("en",),
#      55     preserve_formatting: bool = False,
#      56 ) -> FetchedTranscript:
#      57     """
#      58     Retrieves the transcript for a single video. This is just a shortcut for
#      59     calling:
#    (...)     68     :param preserve_formatting: whether to keep select HTML text formatting
#      69     """
#      70     return (
# ---> 71         self.list(video_id)
#      72         .find_transcript(languages)
#      73         .fetch(preserve_formatting=preserve_formatting)
#      74     )
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_api.py:127, in YouTubeTranscriptApi.list(self, video_id)
#      76 def list(
#      77     self,
#      78     video_id: str,
#      79 ) -> TranscriptList:
#      80     """
#      81     Retrieves the list of transcripts which are available for a given video. It
#      82     returns a `TranscriptList` object which is iterable and provides methods to
#    (...)    125         Make sure that this is the actual ID, NOT the full URL to the video!
#     126     """
# --> 127     return self._fetcher.fetch(video_id)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_transcripts.py:356, in TranscriptListFetcher.fetch(self, video_id)
#     352 def fetch(self, video_id: str) -> TranscriptList:
#     353     return TranscriptList.build(
#     354         self._http_client,
#     355         video_id,
# --> 356         self._fetch_captions_json(video_id),
#     357     )
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_transcripts.py:361, in TranscriptListFetcher._fetch_captions_json(self, video_id, try_number)
#     359 def _fetch_captions_json(self, video_id: str, try_number: int = 0) -> Dict:
#     360     try:
# --> 361         html = self._fetch_video_html(video_id)
#     362         api_key = self._extract_innertube_api_key(html, video_id)
#     363         innertube_data = self._fetch_innertube_data(video_id, api_key)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_transcripts.py:433, in TranscriptListFetcher._fetch_video_html(self, video_id)
#     432 def _fetch_video_html(self, video_id: str) -> str:
# --> 433     html = self._fetch_html(video_id)
#     434     if 'action="https://consent.youtube.com/s"' in html:
#     435         self._create_consent_cookie(html, video_id)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/youtube_transcript_api/_transcripts.py:442, in TranscriptListFetcher._fetch_html(self, video_id)
#     441 def _fetch_html(self, video_id: str) -> str:
# --> 442     response = self._http_client.get(WATCH_URL.format(video_id=video_id))
#     443     return unescape(_raise_http_errors(response, video_id).text)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/urllib3/response.py:1250, in HTTPResponse.stream(self, amt, decode_content)
#    1234 """
#    1235 A generator wrapper for the read() method. A call will block until
#    1236 ``amt`` bytes have been read from the connection or until the
#    (...)   1247     'content-encoding' header.
#    1248 """
#    1249 if self.chunked and self.supports_chunked_reads():
# -> 1250     yield from self.read_chunked(amt, decode_content=decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/urllib3/response.py:1421, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1419     if self.chunk_left == 0:
#    1420         break
# -> 1421     chunk = self._handle_chunk(amt)
#    1422 decoded = self._decode(
#    1423     chunk,
#    1424     decode_content=decode_content,
#    1425     flush_decoder=False,
#    1426     max_length=amt,
#    1427 )
#    1428 if decoded:
#
# File ~/work/ytranscript/.venv/lib/python3.13/site-packages/urllib3/response.py:1354, in HTTPResponse._handle_chunk(self, amt)
#    1352     self.chunk_left = None
#    1353 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1354     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1355     self.chunk_left = self.chunk_left - amt
#    1356     returned_chunk = value
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/http/client.py:642, in HTTPResponse._safe_read(self, amt)
#     635 def _safe_read(self, amt):
#     636     """Read the number of bytes requested.
#     637
#     638     This function should be used when <amt> bytes "should" be present for
#     639     reading. If the bytes are truly not available (due to EOF), then the
#     640     IncompleteRead exception can be used to detect the problem.
#     641     """
# --> 642     data = self.fp.read(amt)
#     643     if len(data) < amt:
#     644         raise IncompleteRead(data, amt-len(data))
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.13.7-linux-x86_64-gnu/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# filtered = {
#     url: data
#     for url, data in result.items()
#     if data.get("transcript", "") != ""
# }
